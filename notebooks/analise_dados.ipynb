# %%
import pandas as pd

# %%
df = pd.read_csv('..\\data\\processed\\CPGF_consolidado_final.csv', sep=';')
df.head()
# Out:
#    cod_orgao_superior       nome_orgao_superior  cod_orgao  \
# 0               63000  Advocacia-Geral Da União      63000
# 1               63000  Advocacia-Geral Da União      63000
# 2               63000  Advocacia-Geral Da União      63000
# 3               63000  Advocacia-Geral Da União      63000
# 4               63000  Advocacia-Geral Da União      63000
#
#                                           nome_orgao  cod_unid_gestora  \
# 0  Advocacia-Geral Da União - Unidades Com Víncul...            110161
# 1  Advocacia-Geral Da União - Unidades Com Víncul...            110161
# 2  Advocacia-Geral Da União - Unidades Com Víncul...            110161
# 3  Advocacia-Geral Da União - Unidades Com Víncul...            110161
# 4  Advocacia-Geral Da União - Unidades Com Víncul...            110161
#
#                               nome_unid_gestora  ano_extrato  mes_extrato  \
# 0  Superintendencia Reg. De Admin. Da 1ª Regiao         2025            2
# 1  Superintendencia Reg. De Admin. Da 1ª Regiao         2025            2
# 2  Superintendencia Reg. De Admin. Da 1ª Regiao         2025            2
# 3  Superintendencia Reg. De Admin. Da 1ª Regiao         2025            2
# 4  Superintendencia Reg. De Admin. Da 1ª Regiao         2025            2
#
#      cpf_portador                   nome_portador  cnpj_cpf_favorecido  \
# 0  ***.562.861-**  Antonio Carlos Melo Dos Santos       19702338000113
# 1  ***.562.861-**  Antonio Carlos Melo Dos Santos                   -2
# 2  ***.562.861-**  Antonio Carlos Melo Dos Santos        4071139000187
# 3  ***.903.253-**       Francisco Pereira Tavares        4415154000286
# 4  ***.562.861-**  Antonio Carlos Melo Dos Santos       13288921000143
#
#                                    nome_favorecido                transacao  \
# 0  Bsbrio Comercio De Armarinhos E Perfumaria Ltda  Compra A/V - R$ - Apres
# 1                                    Nao Se Aplica        Saque Cash/Atm Bb
# 2                          Leitura Taguatinga Ltda  Compra A/V - R$ - Apres
# 3                         Casa Do Eletricista Ltda  Compra A/V - R$ - Apres
# 4                   Jose Pereira De Souza Molduras  Compra A/V - R$ - Apres
#
#   data_transacao  valor_transacao
# 0     2025-01-22            83.88
# 1     2025-01-24           650.00
# 2     2025-01-24            25.80
# 3     2025-01-22           225.00
# 4     2025-01-20            70.00

# %% [markdown]
# ### Criação de KPIS

# %% [markdown]
# Valor total gasto em sigilo X Gastos com portadores identificados \
# Percentual de transparência desses gastos \
# Qual ministério possui o maior volume de dinheiro gasto sigilosamente

# %%
filtro_sigilosos = df['cpf_portador'] == 'sigiloso'

total_sigiloso = df[filtro_sigilosos]['valor_transacao'].sum()
total_identificado = df[~filtro_sigilosos]['valor_transacao'].sum()

print(f"Gastos Sigilosos ou Saques: R$ {total_sigiloso:.2f}")
print(f"Gastos com CPF identificado: R$ {total_identificado:.2f}")
# Out:
# Gastos Sigilosos ou Saques: R$ 32129166.38
# Gastos com CPF identificado: R$ 64341149.10

# %%
total_transacao = df['valor_transacao'].sum()

print(f"Total Gasto: R$ {total_transacao:,.2f}")

percent_transp = (total_identificado / total_transacao) * 100 

print(f"Percentual de transparencia: {percent_transp:.2f}%")
# Out:
# Total Gasto: R$ 96,470,315.48
# Percentual de transparencia: 66.70%

# %%
orgSup_gastos_sigilos = df[filtro_sigilosos].groupby(by='nome_orgao_superior')['valor_transacao'].sum().sort_values(ascending=False)

orgSup_gastos_sigilos.head()
# Out:
# nome_orgao_superior
# Ministério Da Justiça E Segurança Pública    25134609.96
# Presidência Da República                      6163663.00
# Ministério Da Fazenda                          821600.00
# Ministério Da Defesa                             9293.42
# Name: valor_transacao, dtype: float64

# %% [markdown]
# Top 5 orgaos superiores que mais gastaram no total com e sem sigilo?

# %%
orgSup_gastos_total = df.groupby(by='nome_orgao_superior')['valor_transacao'].sum().sort_values(ascending=False)

orgSup_gastos_total.head(5)
# Out:
# nome_orgao_superior
# Ministério Da Justiça E Segurança Pública    32372205.03
# Ministério Da Defesa                         16538553.47
# Ministério Da Educação                       13705189.29
# Ministério Do Planejamento E Orçamento        8068153.48
# Presidência Da República                      6519917.64
# Name: valor_transacao, dtype: float64

# %% [markdown]
# TOP 10 Órgãos Subordinados de gastos totais?

# %%
orgSub_gastos_total = df.groupby(by='nome_orgao')['valor_transacao'].sum().sort_values(ascending=False)

orgSub_gastos_total.head(10)
# Out:
# nome_orgao
# Polícia Federal                                                       30906376.84
# Comando Do Exército                                                    8593281.85
# Fundação Instituto Brasileiro De Geografia E Estatística               8050378.61
# Presidência Da República                                               6287420.50
# Comando Da Marinha                                                     5271502.27
# Instituto Chico Mendes De Conservação Da Biodiversidade                2884370.71
# Instituto Nacional De Colonização E Reforma Agrária                    2061955.80
# Ministério Da Agricultura E Pecuária - Unidades Com Vínculo Direto     1413668.29
# Ministério Da Fazenda - Unidades Com Vínculo Direto                    1223721.16
# Fundo Do Exército                                                      1184178.62
# Name: valor_transacao, dtype: float64
